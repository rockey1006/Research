# %% [markdown]
# <a href="https://colab.research.google.com/github/rockey1006/Research/blob/master/VAE_MNIST_Resize_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/Accuracy.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/Accuracy')

# %%
# !python /content/Accuracy/measure_VAE_accuracy.py \
# Out:
# 2020-07-06 01:02:32.245908: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-06 01:02:34.434908: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-06 01:02:34.438215: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-06 01:02:34.438283: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (6229d05b825e): /proc/driver/nvidia/version does not exist
# 2020-07-06 01:02:34.444132: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2200190000 Hz
# 2020-07-06 01:02:34.444386: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19c3100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/sampling_vae.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/resize')

# %%
from PIL import Image
import os.path
import glob
def convertjpg(jpgfile,outdir,width=28,height=28):
    img=Image.open(jpgfile)
    try:
        new_img=img.resize((width,height),Image.BILINEAR)   
        new_img.save(os.path.join(outdir,os.path.basename(jpgfile)))
    except Exception as e:
        print(e)
for jpgfile in glob.glob("/content/resize/sampling_vae/*.png"):
    convertjpg(jpgfile,"/content/VAE_Resize")

# %%
# !zip -r /content/file.zip /content/VAE_Resize
# Out:
#   adding: content/VAE_Resize/ (stored 0%)
#   adding: content/VAE_Resize/60.png (stored 0%)
#   adding: content/VAE_Resize/355.png (stored 0%)
#   adding: content/VAE_Resize/132.png (stored 0%)
#   adding: content/VAE_Resize/306.png (stored 0%)
#   adding: content/VAE_Resize/87.png (stored 0%)
#   adding: content/VAE_Resize/249.png (stored 0%)
#   adding: content/VAE_Resize/5.png (stored 0%)
#   adding: content/VAE_Resize/331.png (stored 0%)
#   adding: content/VAE_Resize/317.png (stored 0%)
#   adding: content/VAE_Resize/154.png (stored 0%)
#   adding: content/VAE_Resize/145.png (stored 0%)
#   adding: content/VAE_Resize/239.png (stored 0%)
#   adding: content/VAE_Resize/49.png (stored 0%)
#   adding: content/VAE_Resize/123.png (stored 0%)
#   adding: content/VAE_Resize/148.png (stored 0%)
#   adding: content/VAE_Resize/298.png (stored 0%)
#   adding: content/VAE_Resize/253.png (stored 0%)
#   adding: content/VAE_Resize/242.png (stored 0%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip")
